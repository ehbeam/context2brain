# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
import torch.optim as optim
torch.manual_seed(42)

import numpy as np
import pandas as pd

from utilities import load_coordinates, load_dtm, load_mini_batches, plot_loss
from utilities import report_macro, report_class, compute_roc, compute_prc, plot_curves
# %matplotlib inline

# %% [markdown]
# # Specify model hyperparameters

# %%
n_epochs = 500
batch_size = 64
lr = 0.001
weight_decay = 0.00001

# %% [markdown]
# # Specify plotting parameters

# %%
color = "#873434"
cmap = "Reds"
prefix = "occ" # Prefix for plot file names

# %% [markdown]
# # Load the data
#
# ## Brain activation coordinates

# %%
act_bin = load_coordinates()
n_structs = act_bin.shape[1]
print("{:12s}{}".format("Documents", act_bin.shape[0]))
print("{:12s}{}".format("Structures", n_structs))
# Out:
# Documents   18155
# Structures  114

# %% [markdown]
# ## Term embeddings

# %%
vsm = pd.read_csv("data/text/glove_gen_n100_win15_min5_iter500_190428.txt", 
                  sep = " ", index_col=0, header=0)
print("{:21s}{}".format("Embedding Dimension", act_bin.shape[0]))
print("{:21s}{}".format("Terms", n_structs))
# Out:
# Embedding Dimension  18155
# Terms                114

# %% [markdown]
# ## Document-term matrix

# %%
dtm_bin = load_dtm()
dtm_bin = dtm_bin[dtm_bin.columns.intersection(vsm.index)]
n_terms = dtm_bin.shape[1]
print("{:12s}{}".format("Documents", dtm_bin.shape[0]))
print("{:12s}{}".format("Terms", n_terms))
# Out:
# Documents   18155
# Terms       1542

# %% [markdown]
# # Split the data
#
# ## Training and dev sets

# %%
splits = {}
for split in ["train", "dev"]:
    splits[split] = [int(pmid.strip()) for pmid in open("data/splits/{}.txt".format(split), "r").readlines()]

# %% [markdown]
# ## Randomized mini-batches

# %%
X = dtm_bin.loc[splits["train"]].transpose().values
Y = act_bin.loc[splits["train"]].transpose().values
mini_batches = load_mini_batches(X, Y, mini_batch_size=batch_size, seed=42)

# %% [markdown]
# # Specify the classifier

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(n_terms, 100)
        self.fc2 = nn.Linear(100, 100)
        self.fc3 = nn.Linear(100, 100)
        self.fc4 = nn.Linear(100, 100)
        self.fc5 = nn.Linear(100, 100)
        self.dropout1 = nn.Dropout(p=0.5),
        self.fc6 = nn.Linear(100, 100)
        self.dropout2 = nn.Dropout(p=0.5),
        self.fc7 = nn.Linear(100, 100)
        self.dropout3 = nn.Dropout(p=0.5),
        self.fc8 = nn.Linear(100, n_structs)
        
        # Xavier initialization for weights
        for fc in [self.fc1, self.fc2, self.fc3, self.fc4,
                   self.fc5, self.fc6, self.fc7, self.fc8]:
            nn.init.xavier_uniform_(fc.weight)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.relu(self.fc4(x))
        x = F.relu(self.fc5(x))
        x = F.dropout(x)
        x = F.relu(self.fc6(x))
        x = F.dropout(x)
        x = F.relu(self.fc7(x))
        x = F.dropout(x)
        x = torch.sigmoid(self.fc8(x))
        return x

# %%
net = Net()
criterion = F.binary_cross_entropy
optimizer = optim.Adam(net.parameters(), lr=lr, weight_decay=weight_decay)

# %% [markdown]
# # Train the classifier

# %%
net_file = "models/classifier_{}.pt".format(prefix)
if not os.path.exists(outfile):
    
    running_loss = []
    for epoch in range(n_epochs):  # Loop over the dataset multiple times
        for i, data in enumerate(mini_batches):

            # Get the inputs
            inputs, labels = data
            inputs = Variable(torch.from_numpy(inputs.T).float())
            labels = Variable(torch.from_numpy(labels.T).float())

            # Zero the parameter gradients
            optimizer.zero_grad()

            # Forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

        # Print running loss after each epoch
        running_loss += [loss.item()]
        if epoch % (n_epochs/20) == (n_epochs/20) - 1:
            print("Epoch {:3d} \t Loss {:6.6f}".format(epoch + 1, running_loss[-1] / 100))
    
    # Export the trained model
    torch.save(Net().state_dict(), net_file)

else:
    net.load_state_dict(torch.load(net_file))
# Out:
# Epoch  25 	 Loss 0.004427
# Epoch  50 	 Loss 0.004353
# Epoch  75 	 Loss 0.004178
# Epoch 100 	 Loss 0.004046
# Epoch 125 	 Loss 0.004133
# Epoch 150 	 Loss 0.004116
# Epoch 175 	 Loss 0.004063
# Epoch 200 	 Loss 0.004017
# Epoch 225 	 Loss 0.004032
# Epoch 250 	 Loss 0.004029
# Epoch 275 	 Loss 0.003921
# Epoch 300 	 Loss 0.003942
# Epoch 325 	 Loss 0.003902
# Epoch 350 	 Loss 0.003799
# Epoch 375 	 Loss 0.003969
# Epoch 400 	 Loss 0.003914
# Epoch 425 	 Loss 0.003933
# Epoch 450 	 Loss 0.003923
# Epoch 475 	 Loss 0.003832
# Epoch 500 	 Loss 0.003876

# %% [markdown]
# ## Plot the loss over training iterations

# %%
plot_loss(prefix, running_loss, xlab="Epoch", ylab="Loss", color=color)

# %% [markdown]
# # Evaluate the classifier

# %%
def report_curves(data_set, name): 
    with torch.no_grad():
        inputs, labels = data_set[0]
        inputs = Variable(torch.from_numpy(inputs.T).float())
        labels = Variable(torch.from_numpy(labels.T).float())
        pred_probs = net(inputs).float()
        fpr, tpr = compute_roc(labels, pred_probs)
        prec, rec = compute_prc(labels, pred_probs)
        plot_curves("{}_roc".format(name), fpr, tpr, diag=True, alpha=0.25,
                    color=color, xlab="1 - Specificity", ylab="Sensitivity")
        plot_curves("{}_prc".format(name), rec, prec, diag=False, alpha=0.5,
                    color=color, xlab="Recall", ylab="Precision")
        
def report_metrics(data_set):
    with torch.no_grad():
        inputs, labels = data_set[0]
        inputs = Variable(torch.from_numpy(inputs.T).float())
        labels = Variable(torch.from_numpy(labels.T).float())
        outputs = net(inputs)
        predictions = (outputs > 0.5).float() * 1
        print("-" * 50 + "\nMACRO-AVERAGED TOTAL\n" + "-" * 50)
        report_macro(labels, predictions)
        print("\n" + "-" * 50 + "\n\n")
        for i in range(n_structs):
            print("-" * 50 + "\n" + act_bin.columns[i].title().replace("_", " ") + "\n" + "-" * 50)
            report_class(labels[:,i], predictions[:,i])
            print("")

# %% [markdown]
# ## Training set performance

# %%
X_train = dtm_bin.loc[splits["train"]].transpose().values
Y_train = act_bin.loc[splits["train"]].transpose().values
train_set = load_mini_batches(X_train, Y_train, mini_batch_size=len(splits["train"]), seed=42)
report_curves(train_set, "{}_train".format(prefix))

# %%
report_metrics(train_set)
# Out:
# --------------------------------------------------
# MACRO-AVERAGED TOTAL
# --------------------------------------------------
# F1         0.5421
# Precision  0.6649
# Recall     0.5044
# Accuracy   0.8050
# ROC-AUC    0.6903
#
# --------------------------------------------------
#
#
# --------------------------------------------------
# Left Frontal Pole
# --------------------------------------------------
# F1         0.7454
# Precision  0.7102
# Recall     0.7843
# Accuracy   0.7186
# ROC-AUC    0.7152
#
# --------------------------------------------------
# Left Insular Cortex
# --------------------------------------------------
# F1         0.6809
# Precision  0.7028
# Recall     0.6603
# Accuracy   0.7685
# ROC-AUC    0.7467
#
# --------------------------------------------------
# Left Superior Frontal Gyrus
# --------------------------------------------------
# F1         0.7341
# Precision  0.7243
# Recall     0.7441
# Accuracy   0.7351
# ROC-AUC    0.7353
#
# --------------------------------------------------
# Left Middle Frontal Gyrus
# --------------------------------------------------
# F1         0.7754
# Precision  0.7593
# Recall     0.7923
# Accuracy   0.7502
# ROC-AUC    0.7461
#
# --------------------------------------------------
# Left Inferior Frontal Gyrus Pars Triangularis
# --------------------------------------------------
# F1         0.6185
# Precision  0.6627
# Recall     0.5798
# Accuracy   0.7182
# ROC-AUC    0.6940
#
# --------------------------------------------------
# Left Inferior Frontal Gyrus Pars Opercularis
# --------------------------------------------------
# F1         0.7039
# Precision  0.6943
# Recall     0.7138
# Accuracy   0.7316
# ROC-AUC    0.7299
#
# --------------------------------------------------
# Left Precentral Gyrus
# --------------------------------------------------
# F1         0.8134
# Precision  0.7737
# Recall     0.8574
# Accuracy   0.7683
# ROC-AUC    0.7491
#
# --------------------------------------------------
# Left Temporal Pole
# --------------------------------------------------
# F1         0.4346
# Precision  0.6201
# Recall     0.3345
# Accuracy   0.7928
# ROC-AUC    0.6353
#
# --------------------------------------------------
# Left Superior Temporal Gyrus Anterior Division
# --------------------------------------------------
# F1         0.5710
# Precision  0.6251
# Recall     0.5255
# Accuracy   0.8577
# ROC-AUC    0.7281
#
# --------------------------------------------------
# Left Superior Temporal Gyrus Posterior Division
# --------------------------------------------------
# F1         0.7729
# Precision  0.7246
# Recall     0.8281
# Accuracy   0.8232
# ROC-AUC    0.8243
#
# --------------------------------------------------
# Left Middle Temporal Gyrus Anterior Division
# --------------------------------------------------
# F1         0.4493
# Precision  0.5879
# Recall     0.3636
# Accuracy   0.8650
# ROC-AUC    0.6591
#
# --------------------------------------------------
# Left Middle Temporal Gyrus Posterior Division
# --------------------------------------------------
# F1         0.6878
# Precision  0.6776
# Recall     0.6984
# Accuracy   0.8148
# ROC-AUC    0.7806
#
# --------------------------------------------------
# Left Middle Temporal Gyrus Temporooccipital Part
# --------------------------------------------------
# F1         0.6725
# Precision  0.6596
# Recall     0.6859
# Accuracy   0.7826
# ROC-AUC    0.7576
#
# --------------------------------------------------
# Left Inferior Temporal Gyrus Anterior Division
# --------------------------------------------------
# F1         0.1172
# Precision  0.5906
# Recall     0.0650
# Accuracy   0.9188
# ROC-AUC    0.5305
#
# --------------------------------------------------
# Left Inferior Temporal Gyrus Posterior Division
# --------------------------------------------------
# F1         0.4885
# Precision  0.6291
# Recall     0.3993
# Accuracy   0.8339
# ROC-AUC    0.6705
#
# --------------------------------------------------
# Left Inferior Temporal Gyrus Temporooccipital Part
# --------------------------------------------------
# F1         0.6298
# Precision  0.6610
# Recall     0.6014
# Accuracy   0.8086
# ROC-AUC    0.7435
#
# --------------------------------------------------
# Left Postcentral Gyrus
# --------------------------------------------------
# F1         0.7448
# Precision  0.7370
# Recall     0.7527
# Accuracy   0.7597
# ROC-AUC    0.7593
#
# --------------------------------------------------
# Left Superior Parietal Lobule
# --------------------------------------------------
# F1         0.7588
# Precision  0.7529
# Recall     0.7649
# Accuracy   0.7892
# ROC-AUC    0.7863
#
# --------------------------------------------------
# Left Supramarginal Gyrus Anterior Division
# --------------------------------------------------
# F1         0.7307
# Precision  0.7321
# Recall     0.7292
# Accuracy   0.7800
# ROC-AUC    0.7722
#
# --------------------------------------------------
# Left Supramarginal Gyrus Posterior Division
# --------------------------------------------------
# F1         0.8038
# Precision  0.7535
# Recall     0.8613
# Accuracy   0.7931
# ROC-AUC    0.7941
#
# --------------------------------------------------
# Left Angular Gyrus
# --------------------------------------------------
# F1         0.7643
# Precision  0.7219
# Recall     0.8121
# Accuracy   0.7698
# ROC-AUC    0.7729
#
# --------------------------------------------------
# Left Lateral Occipital Cortex Superior Division
# --------------------------------------------------
# F1         0.8400
# Precision  0.7994
# Recall     0.8850
# Accuracy   0.8079
# ROC-AUC    0.7955
#
# --------------------------------------------------
# Left Lateral Occipital Cortex Inferior Division
# --------------------------------------------------
# F1         0.7991
# Precision  0.7664
# Recall     0.8346
# Accuracy   0.8130
# ROC-AUC    0.8151
#
# --------------------------------------------------
# Left Intracalcarine Cortex
# --------------------------------------------------
# F1         0.4549
# Precision  0.6212
# Recall     0.3589
# Accuracy   0.8023
# ROC-AUC    0.6468
#
# --------------------------------------------------
# Left Frontal Medial Cortex
# --------------------------------------------------
# F1         0.1469
# Precision  0.5696
# Recall     0.0843
# Accuracy   0.8400
# ROC-AUC    0.5359
#
# --------------------------------------------------
# Left Supplementary Motor Cortex
# --------------------------------------------------
# F1         0.4752
# Precision  0.6322
# Recall     0.3807
# Accuracy   0.7605
# ROC-AUC    0.6462
#
# --------------------------------------------------
# Left Subcallosal Cortex
# --------------------------------------------------
# F1         0.0838
# Precision  0.5385
# Recall     0.0454
# Accuracy   0.8969
# ROC-AUC    0.5205
#
# --------------------------------------------------
# Left Paracingulate Gyrus
# --------------------------------------------------
# F1         0.6846
# Precision  0.6908
# Recall     0.6785
# Accuracy   0.7327
# ROC-AUC    0.7259
#
# --------------------------------------------------
# Left Cingulate Gyrus Anterior Division
# --------------------------------------------------
# F1         0.6220
# Precision  0.6716
# Recall     0.5793
# Accuracy   0.7308
# ROC-AUC    0.7019
#
# --------------------------------------------------
# Left Cingulate Gyrus Posterior Division
# --------------------------------------------------
# F1         0.4967
# Precision  0.6797
# Recall     0.3913
# Accuracy   0.7515
# ROC-AUC    0.6536
#
# --------------------------------------------------
# Left Precuneous Cortex
# --------------------------------------------------
# F1         0.7038
# Precision  0.6839
# Recall     0.7248
# Accuracy   0.7371
# ROC-AUC    0.7356
#
# --------------------------------------------------
# Left Cuneal Cortex
# --------------------------------------------------
# F1         0.3985
# Precision  0.6196
# Recall     0.2937
# Accuracy   0.7956
# ROC-AUC    0.6198
#
# --------------------------------------------------
# Left Frontal Orbital Cortex
# --------------------------------------------------
# F1         0.6847
# Precision  0.6746
# Recall     0.6950
# Accuracy   0.7378
# ROC-AUC    0.7313
#
# --------------------------------------------------
# Left Parahippocampal Gyrus Anterior Division
# --------------------------------------------------
# F1         0.4686
# Precision  0.5985
# Recall     0.3851
# Accuracy   0.8533
# ROC-AUC    0.6665
#
# --------------------------------------------------
# Left Parahippocampal Gyrus Posterior Division
# --------------------------------------------------
# F1         0.3800
# Precision  0.6257
# Recall     0.2728
# Accuracy   0.8424
# ROC-AUC    0.6189
#
# --------------------------------------------------
# Left Lingual Gyrus
# --------------------------------------------------
# F1         0.6975
# Precision  0.6920
# Recall     0.7030
# Accuracy   0.7847
# ROC-AUC    0.7662
#
# --------------------------------------------------
# Left Temporal Fusiform Cortex Anterior Division
# --------------------------------------------------
# F1         0.0506
# Precision  0.4915
# Recall     0.0267
# Accuracy   0.9333
# ROC-AUC    0.5123
#
# --------------------------------------------------
# Left Temporal Fusiform Cortex Posterior Division
# --------------------------------------------------
# F1         0.6141
# Precision  0.6646
# Recall     0.5708
# Accuracy   0.8196
# ROC-AUC    0.7370
#
# --------------------------------------------------
# Left Temporal Occipital Fusiform Cortex
# --------------------------------------------------
# F1         0.6714
# Precision  0.6872
# Recall     0.6563
# Accuracy   0.8061
# ROC-AUC    0.7636
#
# --------------------------------------------------
# Left Occipital Fusiform Gyrus
# --------------------------------------------------
# F1         0.7333
# Precision  0.7101
# Recall     0.7580
# Accuracy   0.8077
# ROC-AUC    0.7962
#
# --------------------------------------------------
# Left Frontal Operculum Cortex
# --------------------------------------------------
# F1         0.5814
# Precision  0.6422
# Recall     0.5311
# Accuracy   0.7573
# ROC-AUC    0.6968
#
# --------------------------------------------------
# Left Central Opercular Cortex
# --------------------------------------------------
# F1         0.6776
# Precision  0.7198
# Recall     0.6401
# Accuracy   0.7861
# ROC-AUC    0.7526
#
# --------------------------------------------------
# Left Parietal Operculum Cortex
# --------------------------------------------------
# F1         0.6668
# Precision  0.7192
# Recall     0.6215
# Accuracy   0.8133
# ROC-AUC    0.7586
#
# --------------------------------------------------
# Left Planum Polare
# --------------------------------------------------
# F1         0.5556
# Precision  0.6533
# Recall     0.4833
# Accuracy   0.8417
# ROC-AUC    0.7086
#
# --------------------------------------------------
# Left Heschls Gyrus
# --------------------------------------------------
# F1         0.6530
# Precision  0.6862
# Recall     0.6229
# Accuracy   0.8548
# ROC-AUC    0.7714
#
# --------------------------------------------------
# Left Planum Temporale
# --------------------------------------------------
# F1         0.7437
# Precision  0.7337
# Recall     0.7540
# Accuracy   0.8323
# ROC-AUC    0.8118
#
# --------------------------------------------------
# Left Supracalcarine Cortex
# --------------------------------------------------
# F1         0.3126
# Precision  0.6156
# Recall     0.2095
# Accuracy   0.8194
# ROC-AUC    0.5888
#
# --------------------------------------------------
# Left Occipital Pole
# --------------------------------------------------
# F1         0.6266
# Precision  0.6712
# Recall     0.5876
# Accuracy   0.7954
# ROC-AUC    0.7344
#
# --------------------------------------------------
# Left Thalamus
# --------------------------------------------------
# F1         0.4373
# Precision  0.6392
# Recall     0.3324
# Accuracy   0.7682
# ROC-AUC    0.6313
#
# --------------------------------------------------
# Left Caudate
# --------------------------------------------------
# F1         0.2052
# Precision  0.6206
# Recall     0.1229
# Accuracy   0.8340
# ROC-AUC    0.5535
#
# --------------------------------------------------
# Left Putamen
# --------------------------------------------------
# F1         0.3572
# Precision  0.6342
# Recall     0.2486
# Accuracy   0.7960
# ROC-AUC    0.6031
#
# --------------------------------------------------
# Left Pallidum
# --------------------------------------------------
# F1         0.1164
# Precision  0.5639
# Recall     0.0649
# Accuracy   0.8606
# ROC-AUC    0.5283
#
# --------------------------------------------------
# Left Hippocampus
# --------------------------------------------------
# F1         0.5885
# Precision  0.6344
# Recall     0.5488
# Accuracy   0.8206
# ROC-AUC    0.7262
#
# --------------------------------------------------
# Left Amygdala
# --------------------------------------------------
# F1         0.3542
# Precision  0.5868
# Recall     0.2537
# Accuracy   0.8453
# ROC-AUC    0.6089
#
# --------------------------------------------------
# Left Accumbens
# --------------------------------------------------
# F1         0.0660
# Precision  0.6716
# Recall     0.0347
# Accuracy   0.9221
# ROC-AUC    0.5166
#
# --------------------------------------------------
# Left Brainstem
# --------------------------------------------------
# F1         0.0764
# Precision  0.5175
# Recall     0.0413
# Accuracy   0.8906
# ROC-AUC    0.5183
#
# --------------------------------------------------
# Left Cerebellum
# --------------------------------------------------
# F1         0.5044
# Precision  0.6383
# Recall     0.4170
# Accuracy   0.7324
# ROC-AUC    0.6512
#
# --------------------------------------------------
# Right Frontal Pole
# --------------------------------------------------
# F1         0.7572
# Precision  0.7320
# Recall     0.7843
# Accuracy   0.7280
# ROC-AUC    0.7229
#
# --------------------------------------------------
# Right Insular Cortex
# --------------------------------------------------
# F1         0.7001
# Precision  0.7169
# Recall     0.6841
# Accuracy   0.7784
# ROC-AUC    0.7599
#
# --------------------------------------------------
# Right Superior Frontal Gyrus
# --------------------------------------------------
# F1         0.7471
# Precision  0.7383
# Recall     0.7561
# Accuracy   0.7460
# ROC-AUC    0.7461
#
# --------------------------------------------------
# Right Middle Frontal Gyrus
# --------------------------------------------------
# F1         0.7627
# Precision  0.7721
# Recall     0.7536
# Accuracy   0.7589
# ROC-AUC    0.7591
#
# --------------------------------------------------
# Right Inferior Frontal Gyrus Pars Triangularis
# --------------------------------------------------
# F1         0.6352
# Precision  0.6726
# Recall     0.6018
# Accuracy   0.7445
# ROC-AUC    0.7150
#
# --------------------------------------------------
# Right Inferior Frontal Gyrus Pars Opercularis
# --------------------------------------------------
# F1         0.6811
# Precision  0.6972
# Recall     0.6657
# Accuracy   0.7446
# ROC-AUC    0.7325
#
# --------------------------------------------------
# Right Precentral Gyrus
# --------------------------------------------------
# F1         0.8178
# Precision  0.7958
# Recall     0.8411
# Accuracy   0.7825
# ROC-AUC    0.7712
#
# --------------------------------------------------
# Right Temporal Pole
# --------------------------------------------------
# F1         0.4898
# Precision  0.6268
# Recall     0.4019
# Accuracy   0.7891
# ROC-AUC    0.6607
#
# --------------------------------------------------
# Right Superior Temporal Gyrus Anterior Division
# --------------------------------------------------
# F1         0.5291
# Precision  0.6302
# Recall     0.4559
# Accuracy   0.8557
# ROC-AUC    0.6990
#
# --------------------------------------------------
# Right Superior Temporal Gyrus Posterior Division
# --------------------------------------------------
# F1         0.7200
# Precision  0.7116
# Recall     0.7287
# Accuracy   0.8198
# ROC-AUC    0.7955
#
# --------------------------------------------------
# Right Middle Temporal Gyrus Anterior Division
# --------------------------------------------------
# F1         0.4007
# Precision  0.6238
# Recall     0.2951
# Accuracy   0.8649
# ROC-AUC    0.6315
#
# --------------------------------------------------
# Right Middle Temporal Gyrus Posterior Division
# --------------------------------------------------
# F1         0.6584
# Precision  0.6693
# Recall     0.6479
# Accuracy   0.8097
# ROC-AUC    0.7607
#
# --------------------------------------------------
# Right Middle Temporal Gyrus Temporooccipital Part
# --------------------------------------------------
# F1         0.6204
# Precision  0.6516
# Recall     0.5921
# Accuracy   0.7591
# ROC-AUC    0.7172
#
# --------------------------------------------------
# Right Inferior Temporal Gyrus Anterior Division
# --------------------------------------------------
# F1         0.0799
# Precision  0.5976
# Recall     0.0428
# Accuracy   0.9310
# ROC-AUC    0.5203
#
# --------------------------------------------------
# Right Inferior Temporal Gyrus Posterior Division
# --------------------------------------------------
# F1         0.3468
# Precision  0.6146
# Recall     0.2416
# Accuracy   0.8665
# ROC-AUC    0.6078
#
# --------------------------------------------------
# Right Inferior Temporal Gyrus Temporooccipital Part
# --------------------------------------------------
# F1         0.5194
# Precision  0.6434
# Recall     0.4355
# Accuracy   0.8004
# ROC-AUC    0.6780
#
# --------------------------------------------------
# Right Postcentral Gyrus
# --------------------------------------------------
# F1         0.7127
# Precision  0.7144
# Recall     0.7110
# Accuracy   0.7512
# ROC-AUC    0.7465
#
# --------------------------------------------------
# Right Superior Parietal Lobule
# --------------------------------------------------
# F1         0.6964
# Precision  0.7206
# Recall     0.6737
# Accuracy   0.7869
# ROC-AUC    0.7625
#
# --------------------------------------------------
# Right Supramarginal Gyrus Anterior Division
# --------------------------------------------------
# F1         0.6280
# Precision  0.6941
# Recall     0.5735
# Accuracy   0.7839
# ROC-AUC    0.7278
#
# --------------------------------------------------
# Right Supramarginal Gyrus Posterior Division
# --------------------------------------------------
# F1         0.7782
# Precision  0.7477
# Recall     0.8112
# Accuracy   0.7820
# ROC-AUC    0.7836
#
# --------------------------------------------------
# Right Angular Gyrus
# --------------------------------------------------
# F1         0.7673
# Precision  0.7402
# Recall     0.7964
# Accuracy   0.7688
# ROC-AUC    0.7700
#
# --------------------------------------------------
# Right Lateral Occipital Cortex Superior Division
# --------------------------------------------------
# F1         0.8043
# Precision  0.7796
# Recall     0.8306
# Accuracy   0.7877
# ROC-AUC    0.7854
#
# --------------------------------------------------
# Right Lateral Occipital Cortex Inferior Division
# --------------------------------------------------
# F1         0.7579
# Precision  0.7471
# Recall     0.7690
# Accuracy   0.7978
# ROC-AUC    0.7935
#
# --------------------------------------------------
# Right Intracalcarine Cortex
# --------------------------------------------------
# F1         0.4918
# Precision  0.6260
# Recall     0.4049
# Accuracy   0.7942
# ROC-AUC    0.6630
#
# --------------------------------------------------
# Right Frontal Medial Cortex
# --------------------------------------------------
# F1         0.1399
# Precision  0.5605
# Recall     0.0799
# Accuracy   0.8397
# ROC-AUC    0.5339
#
# --------------------------------------------------
# Right Supplementary Motor Cortex
# --------------------------------------------------
# F1         0.5203
# Precision  0.6584
# Recall     0.4301
# Accuracy   0.7703
# ROC-AUC    0.6695
#
# --------------------------------------------------
# Right Subcallosal Cortex
# --------------------------------------------------
# F1         0.0816
# Precision  0.5441
# Recall     0.0441
# Accuracy   0.8980
# ROC-AUC    0.5199
#
# --------------------------------------------------
# Right Paracingulate Gyrus
# --------------------------------------------------
# F1         0.7270
# Precision  0.7249
# Recall     0.7291
# Accuracy   0.7448
# ROC-AUC    0.7438
#
# --------------------------------------------------
# Right Cingulate Gyrus Anterior Division
# --------------------------------------------------
# F1         0.7026
# Precision  0.7166
# Recall     0.6892
# Accuracy   0.7393
# ROC-AUC    0.7345
#
# --------------------------------------------------
# Right Cingulate Gyrus Posterior Division
# --------------------------------------------------
# F1         0.5186
# Precision  0.6657
# Recall     0.4248
# Accuracy   0.7437
# ROC-AUC    0.6610
#
# --------------------------------------------------
# Right Precuneous Cortex
# --------------------------------------------------
# F1         0.6732
# Precision  0.6887
# Recall     0.6584
# Accuracy   0.7336
# ROC-AUC    0.7229
#
# --------------------------------------------------
# Right Cuneal Cortex
# --------------------------------------------------
# F1         0.4706
# Precision  0.6362
# Recall     0.3734
# Accuracy   0.7784
# ROC-AUC    0.6485
#
# --------------------------------------------------
# Right Frontal Orbital Cortex
# --------------------------------------------------
# F1         0.7115
# Precision  0.7087
# Recall     0.7144
# Accuracy   0.7649
# ROC-AUC    0.7569
#
# --------------------------------------------------
# Right Parahippocampal Gyrus Anterior Division
# --------------------------------------------------
# F1         0.4631
# Precision  0.6059
# Recall     0.3748
# Accuracy   0.8665
# ROC-AUC    0.6652
#
# --------------------------------------------------
# Right Parahippocampal Gyrus Posterior Division
# --------------------------------------------------
# F1         0.2821
# Precision  0.6029
# Recall     0.1842
# Accuracy   0.8704
# ROC-AUC    0.5823
#
# --------------------------------------------------
# Right Lingual Gyrus
# --------------------------------------------------
# F1         0.6894
# Precision  0.6960
# Recall     0.6829
# Accuracy   0.7806
# ROC-AUC    0.7588
#
# --------------------------------------------------
# Right Temporal Fusiform Cortex Anterior Division
# --------------------------------------------------
# F1         0.0947
# Precision  0.4907
# Recall     0.0524
# Accuracy   0.9380
# ROC-AUC    0.5244
#
# --------------------------------------------------
# Right Temporal Fusiform Cortex Posterior Division
# --------------------------------------------------
# F1         0.5008
# Precision  0.6353
# Recall     0.4133
# Accuracy   0.8525
# ROC-AUC    0.6808
#
# --------------------------------------------------
# Right Temporal Occipital Fusiform Cortex
# --------------------------------------------------
# F1         0.6343
# Precision  0.6885
# Recall     0.5879
# Accuracy   0.8134
# ROC-AUC    0.7435
#
# --------------------------------------------------
# Right Occipital Fusiform Gyrus
# --------------------------------------------------
# F1         0.6952
# Precision  0.7070
# Recall     0.6837
# Accuracy   0.8051
# ROC-AUC    0.7736
#
# --------------------------------------------------
# Right Frontal Operculum Cortex
# --------------------------------------------------
# F1         0.6258
# Precision  0.6724
# Recall     0.5852
# Accuracy   0.7811
# ROC-AUC    0.7277
#
# --------------------------------------------------
# Right Central Opercular Cortex
# --------------------------------------------------
# F1         0.6403
# Precision  0.7084
# Recall     0.5842
# Accuracy   0.8011
# ROC-AUC    0.7398
#
# --------------------------------------------------
# Right Parietal Operculum Cortex
# --------------------------------------------------
# F1         0.6419
# Precision  0.7063
# Recall     0.5883
# Accuracy   0.8269
# ROC-AUC    0.7503
#
# --------------------------------------------------
# Right Planum Polare
# --------------------------------------------------
# F1         0.5531
# Precision  0.6653
# Recall     0.4732
# Accuracy   0.8409
# ROC-AUC    0.7054
#
# --------------------------------------------------
# Right Heschls Gyrus
# --------------------------------------------------
# F1         0.6073
# Precision  0.6662
# Recall     0.5580
# Accuracy   0.8599
# ROC-AUC    0.7453
#
# --------------------------------------------------
# Right Planum Temporale
# --------------------------------------------------
# F1         0.7164
# Precision  0.7406
# Recall     0.6937
# Accuracy   0.8442
# ROC-AUC    0.7988
#
# --------------------------------------------------
# Right Supracalcarine Cortex
# --------------------------------------------------
# F1         0.4430
# Precision  0.6173
# Recall     0.3455
# Accuracy   0.7903
# ROC-AUC    0.6387
#
# --------------------------------------------------
# Right Occipital Pole
# --------------------------------------------------
# F1         0.6502
# Precision  0.6805
# Recall     0.6225
# Accuracy   0.7948
# ROC-AUC    0.7467
#
# --------------------------------------------------
# Right Thalamus
# --------------------------------------------------
# F1         0.3877
# Precision  0.6513
# Recall     0.2760
# Accuracy   0.7740
# ROC-AUC    0.6122
#
# --------------------------------------------------
# Right Caudate
# --------------------------------------------------
# F1         0.1959
# Precision  0.6235
# Recall     0.1162
# Accuracy   0.8211
# ROC-AUC    0.5500
#
# --------------------------------------------------
# Right Putamen
# --------------------------------------------------
# F1         0.3553
# Precision  0.6259
# Recall     0.2481
# Accuracy   0.7968
# ROC-AUC    0.6024
#
# --------------------------------------------------
# Right Pallidum
# --------------------------------------------------
# F1         0.1439
# Precision  0.5571
# Recall     0.0826
# Accuracy   0.8580
# ROC-AUC    0.5358
#
# --------------------------------------------------
# Right Hippocampus
# --------------------------------------------------
# F1         0.5931
# Precision  0.6295
# Recall     0.5608
# Accuracy   0.8295
# ROC-AUC    0.7334
#
# --------------------------------------------------
# Right Amygdala
# --------------------------------------------------
# F1         0.3598
# Precision  0.5728
# Recall     0.2623
# Accuracy   0.8475
# ROC-AUC    0.6120
#
# --------------------------------------------------
# Right Accumbens
# --------------------------------------------------
# F1         0.0540
# Precision  0.6545
# Recall     0.0281
# Accuracy   0.9228
# ROC-AUC    0.5134
#
# --------------------------------------------------
# Right Brainstem
# --------------------------------------------------
# F1         0.0878
# Precision  0.5278
# Recall     0.0479
# Accuracy   0.8791
# ROC-AUC    0.5210
#
# --------------------------------------------------
# Right Cerebellum
# --------------------------------------------------
# F1         0.5078
# Precision  0.6450
# Recall     0.4187
# Accuracy   0.7253
# ROC-AUC    0.6504

# %% [markdown]
# ## Dev set performance

# %%
X_dev = dtm_bin.loc[splits["dev"]].transpose().values
Y_dev = act_bin.loc[splits["dev"]].transpose().values
dev_set = load_mini_batches(X_dev, Y_dev, mini_batch_size=len(splits["dev"]), seed=42)
report_curves(dev_set, "{}_dev".format(prefix))

# %%
report_metrics(dev_set)
# Out:
# --------------------------------------------------
# MACRO-AVERAGED TOTAL
# --------------------------------------------------
# F1         0.3053
# Precision  0.4080
# Recall     0.2844
# Accuracy   0.6954
# /Users/ehbeam/anaconda/envs/ontol/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/ehbeam/anaconda/envs/ontol/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ROC-AUC    0.5434
#
# --------------------------------------------------
#
#
# --------------------------------------------------
# Left Frontal Pole
# --------------------------------------------------
# F1         0.6097
# Precision  0.5509
# Recall     0.6826
# Accuracy   0.5573
# ROC-AUC    0.5556
#
# --------------------------------------------------
# Left Insular Cortex
# --------------------------------------------------
# F1         0.3829
# Precision  0.4201
# Recall     0.3517
# Accuracy   0.5705
# ROC-AUC    0.5278
#
# --------------------------------------------------
# Left Superior Frontal Gyrus
# --------------------------------------------------
# F1         0.5922
# Precision  0.5664
# Recall     0.6205
# Accuracy   0.5859
# ROC-AUC    0.5869
#
# --------------------------------------------------
# Left Middle Frontal Gyrus
# --------------------------------------------------
# F1         0.6211
# Precision  0.5699
# Recall     0.6824
# Accuracy   0.5727
# ROC-AUC    0.5697
#
# --------------------------------------------------
# Left Inferior Frontal Gyrus Pars Triangularis
# --------------------------------------------------
# F1         0.3922
# Precision  0.4261
# Recall     0.3634
# Accuracy   0.5870
# ROC-AUC    0.5399
#
# --------------------------------------------------
# Left Inferior Frontal Gyrus Pars Opercularis
# --------------------------------------------------
# F1         0.4899
# Precision  0.4665
# Recall     0.5159
# Accuracy   0.5529
# ROC-AUC    0.5476
#
# --------------------------------------------------
# Left Precentral Gyrus
# --------------------------------------------------
# F1         0.6776
# Precision  0.6164
# Recall     0.7524
# Accuracy   0.5892
# ROC-AUC    0.5610
#
# --------------------------------------------------
# Left Temporal Pole
# --------------------------------------------------
# F1         0.1616
# Precision  0.3200
# Recall     0.1081
# Accuracy   0.7258
# ROC-AUC    0.5169
#
# --------------------------------------------------
# Left Superior Temporal Gyrus Anterior Division
# --------------------------------------------------
# F1         0.2283
# Precision  0.2929
# Recall     0.1871
# Accuracy   0.7841
# ROC-AUC    0.5471
#
# --------------------------------------------------
# Left Superior Temporal Gyrus Posterior Division
# --------------------------------------------------
# F1         0.4716
# Precision  0.4355
# Recall     0.5143
# Accuracy   0.6002
# ROC-AUC    0.5801
#
# --------------------------------------------------
# Left Middle Temporal Gyrus Anterior Division
# --------------------------------------------------
# F1         0.1398
# Precision  0.2241
# Recall     0.1016
# Accuracy   0.8238
# ROC-AUC    0.5219
#
# --------------------------------------------------
# Left Middle Temporal Gyrus Posterior Division
# --------------------------------------------------
# F1         0.3919
# Precision  0.3821
# Recall     0.4023
# Accuracy   0.6344
# ROC-AUC    0.5664
#
# --------------------------------------------------
# Left Middle Temporal Gyrus Temporooccipital Part
# --------------------------------------------------
# F1         0.4098
# Precision  0.4194
# Recall     0.4007
# Accuracy   0.6289
# ROC-AUC    0.5688
#
# --------------------------------------------------
# Left Inferior Temporal Gyrus Anterior Division
# --------------------------------------------------
# F1         0.0789
# Precision  0.4286
# Recall     0.0435
# Accuracy   0.9229
# ROC-AUC    0.5194
#
# --------------------------------------------------
# Left Inferior Temporal Gyrus Posterior Division
# --------------------------------------------------
# F1         0.2452
# Precision  0.3596
# Recall     0.1860
# Accuracy   0.7830
# ROC-AUC    0.5543
#
# --------------------------------------------------
# Left Inferior Temporal Gyrus Temporooccipital Part
# --------------------------------------------------
# F1         0.3735
# Precision  0.4153
# Recall     0.3393
# Accuracy   0.7192
# ROC-AUC    0.5914
#
# --------------------------------------------------
# Left Postcentral Gyrus
# --------------------------------------------------
# F1         0.5338
# Precision  0.5319
# Recall     0.5357
# Accuracy   0.5672
# ROC-AUC    0.5650
#
# --------------------------------------------------
# Left Superior Parietal Lobule
# --------------------------------------------------
# F1         0.5111
# Precision  0.5104
# Recall     0.5117
# Accuracy   0.5870
# ROC-AUC    0.5768
#
# --------------------------------------------------
# Left Supramarginal Gyrus Anterior Division
# --------------------------------------------------
# F1         0.4691
# Precision  0.4731
# Recall     0.4652
# Accuracy   0.5837
# ROC-AUC    0.5632
#
# --------------------------------------------------
# Left Supramarginal Gyrus Posterior Division
# --------------------------------------------------
# F1         0.5902
# Precision  0.5340
# Recall     0.6597
# Accuracy   0.5672
# ROC-AUC    0.5720
#
# --------------------------------------------------
# Left Angular Gyrus
# --------------------------------------------------
# F1         0.5743
# Precision  0.5385
# Recall     0.6152
# Accuracy   0.5771
# ROC-AUC    0.5797
#
# --------------------------------------------------
# Left Lateral Occipital Cortex Superior Division
# --------------------------------------------------
# F1         0.6782
# Precision  0.6223
# Recall     0.7450
# Accuracy   0.6090
# ROC-AUC    0.5930
#
# --------------------------------------------------
# Left Lateral Occipital Cortex Inferior Division
# --------------------------------------------------
# F1         0.5353
# Precision  0.5268
# Recall     0.5441
# Accuracy   0.5870
# ROC-AUC    0.5822
#
# --------------------------------------------------
# Left Intracalcarine Cortex
# --------------------------------------------------
# F1         0.1514
# Precision  0.3288
# Recall     0.0984
# Accuracy   0.7037
# ROC-AUC    0.5123
#
# --------------------------------------------------
# Left Frontal Medial Cortex
# --------------------------------------------------
# F1         0.0290
# Precision  0.4000
# Recall     0.0150
# Accuracy   0.8524
# ROC-AUC    0.5056
#
# --------------------------------------------------
# Left Supplementary Motor Cortex
# --------------------------------------------------
# F1         0.2472
# Precision  0.4444
# Recall     0.1712
# Accuracy   0.7048
# ROC-AUC    0.5434
#
# --------------------------------------------------
# Left Subcallosal Cortex
# --------------------------------------------------
# F1         0.0460
# Precision  1.0000
# Recall     0.0235
# Accuracy   0.9086
# ROC-AUC    0.5118
#
# --------------------------------------------------
# Left Paracingulate Gyrus
# --------------------------------------------------
# F1         0.4942
# Precision  0.4848
# Recall     0.5040
# Accuracy   0.5694
# ROC-AUC    0.5601
#
# --------------------------------------------------
# Left Cingulate Gyrus Anterior Division
# --------------------------------------------------
# F1         0.3885
# Precision  0.4326
# Recall     0.3526
# Accuracy   0.5771
# ROC-AUC    0.5340
#
# --------------------------------------------------
# Left Cingulate Gyrus Posterior Division
# --------------------------------------------------
# F1         0.2805
# Precision  0.4500
# Recall     0.2038
# Accuracy   0.6949
# ROC-AUC    0.5506
#
# --------------------------------------------------
# Left Precuneous Cortex
# --------------------------------------------------
# F1         0.5180
# Precision  0.4988
# Recall     0.5389
# Accuracy   0.5881
# ROC-AUC    0.5807
#
# --------------------------------------------------
# Left Cuneal Cortex
# --------------------------------------------------
# F1         0.1259
# Precision  0.3269
# Recall     0.0780
# Accuracy   0.7401
# ROC-AUC    0.5136
#
# --------------------------------------------------
# Left Frontal Orbital Cortex
# --------------------------------------------------
# F1         0.4709
# Precision  0.4439
# Recall     0.5014
# Accuracy   0.5694
# ROC-AUC    0.5564
#
# --------------------------------------------------
# Left Parahippocampal Gyrus Anterior Division
# --------------------------------------------------
# F1         0.2105
# Precision  0.3636
# Recall     0.1481
# Accuracy   0.8018
# ROC-AUC    0.5459
#
# --------------------------------------------------
# Left Parahippocampal Gyrus Posterior Division
# --------------------------------------------------
# F1         0.1158
# Precision  0.2619
# Recall     0.0743
# Accuracy   0.8150
# ROC-AUC    0.5168
#
# --------------------------------------------------
# Left Lingual Gyrus
# --------------------------------------------------
# F1         0.4309
# Precision  0.4781
# Recall     0.3922
# Accuracy   0.6189
# ROC-AUC    0.5715
#
# --------------------------------------------------
# Left Temporal Fusiform Cortex Anterior Division
# --------------------------------------------------
# F1         0.0000
# Precision  0.0000
# Recall     0.0000
# Accuracy   0.9350
# ROC-AUC    0.4994
#
# --------------------------------------------------
# Left Temporal Fusiform Cortex Posterior Division
# --------------------------------------------------
# F1         0.3003
# Precision  0.3709
# Recall     0.2523
# Accuracy   0.7126
# ROC-AUC    0.5569
#
# --------------------------------------------------
# Left Temporal Occipital Fusiform Cortex
# --------------------------------------------------
# F1         0.3913
# Precision  0.4348
# Recall     0.3557
# Accuracy   0.6916
# ROC-AUC    0.5886
#
# --------------------------------------------------
# Left Occipital Fusiform Gyrus
# --------------------------------------------------
# F1         0.4124
# Precision  0.4225
# Recall     0.4027
# Accuracy   0.6233
# ROC-AUC    0.5669
#
# --------------------------------------------------
# Left Frontal Operculum Cortex
# --------------------------------------------------
# F1         0.3121
# Precision  0.3679
# Recall     0.2710
# Accuracy   0.6553
# ROC-AUC    0.5411
#
# --------------------------------------------------
# Left Central Opercular Cortex
# --------------------------------------------------
# F1         0.3748
# Precision  0.4118
# Recall     0.3439
# Accuracy   0.6399
# ROC-AUC    0.5596
#
# --------------------------------------------------
# Left Parietal Operculum Cortex
# --------------------------------------------------
# F1         0.2987
# Precision  0.3651
# Recall     0.2527
# Accuracy   0.6432
# ROC-AUC    0.5319
#
# --------------------------------------------------
# Left Planum Polare
# --------------------------------------------------
# F1         0.2422
# Precision  0.3465
# Recall     0.1862
# Accuracy   0.7588
# ROC-AUC    0.5473
#
# --------------------------------------------------
# Left Heschls Gyrus
# --------------------------------------------------
# F1         0.2588
# Precision  0.3308
# Recall     0.2126
# Accuracy   0.7225
# ROC-AUC    0.5428
#
# --------------------------------------------------
# Left Planum Temporale
# --------------------------------------------------
# F1         0.4124
# Precision  0.4484
# Recall     0.3818
# Accuracy   0.6454
# ROC-AUC    0.5773
#
# --------------------------------------------------
# Left Supracalcarine Cortex
# --------------------------------------------------
# F1         0.0857
# Precision  0.3462
# Recall     0.0489
# Accuracy   0.7885
# ROC-AUC    0.5127
#
# --------------------------------------------------
# Left Occipital Pole
# --------------------------------------------------
# F1         0.3592
# Precision  0.4378
# Recall     0.3045
# Accuracy   0.6817
# ROC-AUC    0.5713
#
# --------------------------------------------------
# Left Thalamus
# --------------------------------------------------
# F1         0.1908
# Precision  0.4189
# Recall     0.1235
# Accuracy   0.7104
# ROC-AUC    0.5290
#
# --------------------------------------------------
# Left Caudate
# --------------------------------------------------
# F1         0.0106
# Precision  0.1250
# Recall     0.0056
# Accuracy   0.7952
# ROC-AUC    0.4980
#
# --------------------------------------------------
# Left Putamen
# --------------------------------------------------
# F1         0.1439
# Precision  0.4167
# Recall     0.0870
# Accuracy   0.7379
# ROC-AUC    0.5228
#
# --------------------------------------------------
# Left Pallidum
# --------------------------------------------------
# F1         0.0145
# Precision  0.3333
# Recall     0.0074
# Accuracy   0.8502
# ROC-AUC    0.5024
#
# --------------------------------------------------
# Left Hippocampus
# --------------------------------------------------
# F1         0.3324
# Precision  0.4326
# Recall     0.2699
# Accuracy   0.7302
# ROC-AUC    0.5763
#
# --------------------------------------------------
# Left Amygdala
# --------------------------------------------------
# F1         0.1706
# Precision  0.4286
# Recall     0.1065
# Accuracy   0.8073
# ROC-AUC    0.5370
#
# --------------------------------------------------
# Left Accumbens
# --------------------------------------------------
# F1         0.0247
# Precision  1.0000
# Recall     0.0125
# Accuracy   0.9130
# ROC-AUC    0.5062
#
# --------------------------------------------------
# Left Brainstem
# --------------------------------------------------
# F1         0.0000
# Precision  0.0000
# Recall     0.0000
# Accuracy   0.9086
# ROC-AUC    0.5000
#
# --------------------------------------------------
# Left Cerebellum
# --------------------------------------------------
# F1         0.2457
# Precision  0.3817
# Recall     0.1812
# Accuracy   0.6619
# ROC-AUC    0.5265
#
# --------------------------------------------------
# Right Frontal Pole
# --------------------------------------------------
# F1         0.6459
# Precision  0.5932
# Recall     0.7088
# Accuracy   0.6002
# ROC-AUC    0.5970
#
# --------------------------------------------------
# Right Insular Cortex
# --------------------------------------------------
# F1         0.3954
# Precision  0.4158
# Recall     0.3769
# Accuracy   0.5925
# ROC-AUC    0.5437
#
# --------------------------------------------------
# Right Superior Frontal Gyrus
# --------------------------------------------------
# F1         0.5797
# Precision  0.5681
# Recall     0.5917
# Accuracy   0.5672
# ROC-AUC    0.5670
#
# --------------------------------------------------
# Right Middle Frontal Gyrus
# --------------------------------------------------
# F1         0.5446
# Precision  0.5225
# Recall     0.5688
# Accuracy   0.5507
# ROC-AUC    0.5516
#
# --------------------------------------------------
# Right Inferior Frontal Gyrus Pars Triangularis
# --------------------------------------------------
# F1         0.3966
# Precision  0.4158
# Recall     0.3791
# Accuracy   0.6112
# ROC-AUC    0.5542
#
# --------------------------------------------------
# Right Inferior Frontal Gyrus Pars Opercularis
# --------------------------------------------------
# F1         0.4257
# Precision  0.4225
# Recall     0.4290
# Accuracy   0.5870
# ROC-AUC    0.5518
#
# --------------------------------------------------
# Right Precentral Gyrus
# --------------------------------------------------
# F1         0.6312
# Precision  0.5762
# Recall     0.6978
# Accuracy   0.5573
# ROC-AUC    0.5441
#
# --------------------------------------------------
# Right Temporal Pole
# --------------------------------------------------
# F1         0.1935
# Precision  0.2885
# Recall     0.1456
# Accuracy   0.7247
# ROC-AUC    0.5201
#
# --------------------------------------------------
# Right Superior Temporal Gyrus Anterior Division
# --------------------------------------------------
# F1         0.1475
# Precision  0.2308
# Recall     0.1084
# Accuracy   0.7709
# ROC-AUC    0.5138
#
# --------------------------------------------------
# Right Superior Temporal Gyrus Posterior Division
# --------------------------------------------------
# F1         0.3806
# Precision  0.4046
# Recall     0.3593
# Accuracy   0.6200
# ROC-AUC    0.5524
#
# --------------------------------------------------
# Right Middle Temporal Gyrus Anterior Division
# --------------------------------------------------
# F1         0.1202
# Precision  0.3548
# Recall     0.0724
# Accuracy   0.8227
# ROC-AUC    0.5230
#
# --------------------------------------------------
# Right Middle Temporal Gyrus Posterior Division
# --------------------------------------------------
# F1         0.3510
# Precision  0.3675
# Recall     0.3359
# Accuracy   0.6498
# ROC-AUC    0.5545
#
# --------------------------------------------------
# Right Middle Temporal Gyrus Temporooccipital Part
# --------------------------------------------------
# F1         0.3457
# Precision  0.3908
# Recall     0.3100
# Accuracy   0.6123
# ROC-AUC    0.5358
#
# --------------------------------------------------
# Right Inferior Temporal Gyrus Anterior Division
# --------------------------------------------------
# /Users/ehbeam/anaconda/envs/ontol/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/ehbeam/anaconda/envs/ontol/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# F1         0.0000
# Precision  0.0000
# Recall     0.0000
# Accuracy   0.9273
# ROC-AUC    0.4982
#
# --------------------------------------------------
# Right Inferior Temporal Gyrus Posterior Division
# --------------------------------------------------
# F1         0.1401
# Precision  0.3235
# Recall     0.0894
# Accuracy   0.8513
# ROC-AUC    0.5301
#
# --------------------------------------------------
# Right Inferior Temporal Gyrus Temporooccipital Part
# --------------------------------------------------
# F1         0.2622
# Precision  0.3772
# Recall     0.2009
# Accuracy   0.7335
# ROC-AUC    0.5493
#
# --------------------------------------------------
# Right Postcentral Gyrus
# --------------------------------------------------
# F1         0.4405
# Precision  0.4478
# Recall     0.4335
# Accuracy   0.5441
# ROC-AUC    0.5278
#
# --------------------------------------------------
# Right Superior Parietal Lobule
# --------------------------------------------------
# F1         0.3980
# Precision  0.4457
# Recall     0.3595
# Accuracy   0.6035
# ROC-AUC    0.5515
#
# --------------------------------------------------
# Right Supramarginal Gyrus Anterior Division
# --------------------------------------------------
# F1         0.2989
# Precision  0.3636
# Recall     0.2537
# Accuracy   0.6487
# ROC-AUC    0.5339
#
# --------------------------------------------------
# Right Supramarginal Gyrus Posterior Division
# --------------------------------------------------
# F1         0.5227
# Precision  0.4936
# Recall     0.5556
# Accuracy   0.5374
# ROC-AUC    0.5389
#
# --------------------------------------------------
# Right Angular Gyrus
# --------------------------------------------------
# F1         0.5535
# Precision  0.5116
# Recall     0.6030
# Accuracy   0.5683
# ROC-AUC    0.5718
#
# --------------------------------------------------
# Right Lateral Occipital Cortex Superior Division
# --------------------------------------------------
# F1         0.6168
# Precision  0.5734
# Recall     0.6674
# Accuracy   0.5936
# ROC-AUC    0.5950
#
# --------------------------------------------------
# Right Lateral Occipital Cortex Inferior Division
# --------------------------------------------------
# F1         0.4929
# Precision  0.5073
# Recall     0.4793
# Accuracy   0.6057
# ROC-AUC    0.5846
#
# --------------------------------------------------
# Right Intracalcarine Cortex
# --------------------------------------------------
# F1         0.1951
# Precision  0.3636
# Recall     0.1333
# Accuracy   0.7093
# ROC-AUC    0.5248
#
# --------------------------------------------------
# Right Frontal Medial Cortex
# --------------------------------------------------
# F1         0.0121
# Precision  0.2000
# Recall     0.0063
# Accuracy   0.8205
# ROC-AUC    0.5005
#
# --------------------------------------------------
# Right Supplementary Motor Cortex
# --------------------------------------------------
# F1         0.2710
# Precision  0.4348
# Recall     0.1969
# Accuracy   0.7037
# ROC-AUC    0.5487
#
# --------------------------------------------------
# Right Subcallosal Cortex
# --------------------------------------------------
# F1         0.0000
# Precision  0.0000
# Recall     0.0000
# Accuracy   0.9009
# ROC-AUC    0.4994
#
# --------------------------------------------------
# Right Paracingulate Gyrus
# --------------------------------------------------
# F1         0.5684
# Precision  0.5632
# Recall     0.5738
# Accuracy   0.5903
# ROC-AUC    0.5894
#
# --------------------------------------------------
# Right Cingulate Gyrus Anterior Division
# --------------------------------------------------
# F1         0.5203
# Precision  0.5284
# Recall     0.5125
# Accuracy   0.5837
# ROC-AUC    0.5761
#
# --------------------------------------------------
# Right Cingulate Gyrus Posterior Division
# --------------------------------------------------
# F1         0.3048
# Precision  0.4521
# Recall     0.2300
# Accuracy   0.6685
# ROC-AUC    0.5506
#
# --------------------------------------------------
# Right Precuneous Cortex
# --------------------------------------------------
# F1         0.4699
# Precision  0.5000
# Recall     0.4433
# Accuracy   0.5826
# ROC-AUC    0.5628
#
# --------------------------------------------------
# Right Cuneal Cortex
# --------------------------------------------------
# F1         0.1443
# Precision  0.2933
# Recall     0.0957
# Accuracy   0.7126
# ROC-AUC    0.5087
#
# --------------------------------------------------
# Right Frontal Orbital Cortex
# --------------------------------------------------
# F1         0.4528
# Precision  0.4333
# Recall     0.4742
# Accuracy   0.5848
# ROC-AUC    0.5609
#
# --------------------------------------------------
# Right Parahippocampal Gyrus Anterior Division
# --------------------------------------------------
# F1         0.1848
# Precision  0.3333
# Recall     0.1278
# Accuracy   0.8348
# ROC-AUC    0.5420
#
# --------------------------------------------------
# Right Parahippocampal Gyrus Posterior Division
# --------------------------------------------------
# F1         0.0530
# Precision  0.2105
# Recall     0.0303
# Accuracy   0.8425
# ROC-AUC    0.5055
#
# --------------------------------------------------
# Right Lingual Gyrus
# --------------------------------------------------
# F1         0.4178
# Precision  0.4686
# Recall     0.3769
# Accuracy   0.6101
# ROC-AUC    0.5623
#
# --------------------------------------------------
# Right Temporal Fusiform Cortex Anterior Division
# --------------------------------------------------
# F1         0.0741
# Precision  0.4000
# Recall     0.0408
# Accuracy   0.9449
# ROC-AUC    0.5187
#
# --------------------------------------------------
# Right Temporal Fusiform Cortex Posterior Division
# --------------------------------------------------
# F1         0.1930
# Precision  0.3284
# Recall     0.1366
# Accuracy   0.7974
# ROC-AUC    0.5382
#
# --------------------------------------------------
# Right Temporal Occipital Fusiform Cortex
# --------------------------------------------------
# F1         0.3202
# Precision  0.3988
# Recall     0.2675
# Accuracy   0.6960
# ROC-AUC    0.5601
#
# --------------------------------------------------
# Right Occipital Fusiform Gyrus
# --------------------------------------------------
# F1         0.3694
# Precision  0.4123
# Recall     0.3345
# Accuracy   0.6465
# ROC-AUC    0.5604
#
# --------------------------------------------------
# Right Frontal Operculum Cortex
# --------------------------------------------------
# F1         0.2687
# Precision  0.3005
# Recall     0.2430
# Accuracy   0.6344
# ROC-AUC    0.5134
#
# --------------------------------------------------
# Right Central Opercular Cortex
# --------------------------------------------------
# F1         0.3023
# Precision  0.3757
# Recall     0.2529
# Accuracy   0.6696
# ROC-AUC    0.5435
#
# --------------------------------------------------
# Right Parietal Operculum Cortex
# --------------------------------------------------
# F1         0.2764
# Precision  0.3355
# Recall     0.2350
# Accuracy   0.7059
# ROC-AUC    0.5444
#
# --------------------------------------------------
# Right Planum Polare
# --------------------------------------------------
# F1         0.1786
# Precision  0.2525
# Recall     0.1381
# Accuracy   0.7467
# ROC-AUC    0.5182
#
# --------------------------------------------------
# Right Heschls Gyrus
# --------------------------------------------------
# F1         0.2206
# Precision  0.2768
# Recall     0.1834
# Accuracy   0.7588
# ROC-AUC    0.5369
#
# --------------------------------------------------
# Right Planum Temporale
# --------------------------------------------------
# F1         0.3393
# Precision  0.3918
# Recall     0.2992
# Accuracy   0.6740
# ROC-AUC    0.5594
#
# --------------------------------------------------
# Right Supracalcarine Cortex
# --------------------------------------------------
# F1         0.1395
# Precision  0.3043
# Recall     0.0905
# Accuracy   0.7148
# ROC-AUC    0.5098
#
# --------------------------------------------------
# Right Occipital Pole
# --------------------------------------------------
# F1         0.3527
# Precision  0.4059
# Recall     0.3118
# Accuracy   0.6685
# ROC-AUC    0.5629
#
# --------------------------------------------------
# Right Thalamus
# --------------------------------------------------
# F1         0.1414
# Precision  0.4375
# Recall     0.0843
# Accuracy   0.7192
# ROC-AUC    0.5217
#
# --------------------------------------------------
# Right Caudate
# --------------------------------------------------
# F1         0.0460
# Precision  0.4444
# Recall     0.0242
# Accuracy   0.8172
# ROC-AUC    0.5088
#
# --------------------------------------------------
# Right Putamen
# --------------------------------------------------
# F1         0.1269
# Precision  0.3696
# Recall     0.0766
# Accuracy   0.7423
# ROC-AUC    0.5172
#
# --------------------------------------------------
# Right Pallidum
# --------------------------------------------------
# F1         0.0143
# Precision  0.2500
# Recall     0.0074
# Accuracy   0.8480
# ROC-AUC    0.5017
#
# --------------------------------------------------
# Right Hippocampus
# --------------------------------------------------
# F1         0.2931
# Precision  0.3542
# Recall     0.2500
# Accuracy   0.7291
# ROC-AUC    0.5589
#
# --------------------------------------------------
# Right Amygdala
# --------------------------------------------------
# F1         0.1176
# Precision  0.2750
# Recall     0.0748
# Accuracy   0.8183
# ROC-AUC    0.5184
#
# --------------------------------------------------
# Right Accumbens
# --------------------------------------------------
# F1         0.0286
# Precision  1.0000
# Recall     0.0145
# Accuracy   0.9251
# ROC-AUC    0.5072
#
# --------------------------------------------------
# Right Brainstem
# --------------------------------------------------
# F1         0.0000
# Precision  0.0000
# Recall     0.0000
# Accuracy   0.8767
# ROC-AUC    0.4994
#
# --------------------------------------------------
# Right Cerebellum
# --------------------------------------------------
# F1         0.2774
# Precision  0.4627
# Recall     0.1981
# Accuracy   0.6443
# ROC-AUC    0.5385

# %% [markdown]
# # Map a brain dictionary

# %%
from nilearn import image, plotting
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from matplotlib import font_manager
from scipy.stats import zscore
from wordcloud import WordCloud
from utilities import load_atlas, mni2vox

# %% [markdown]
# ## Compute term activation maps
#
# Inputs are one-hot vectors representing the occurrence of each term. Outputs are probabilities for each brain structure predicted by the occurrence of a given term.

# %%
terms = list(dtm_bin.columns)
term_map = pd.DataFrame(index=act_bin.columns, columns=dtm_bin.columns)

# %%
for i, term in enumerate(terms):
    inputs = np.zeros((1, dtm_bin.shape[1]))
    inputs[0, i] = 1.0
    inputs = Variable(torch.from_numpy(inputs).float())
    pred_probs = net(inputs).float().detach().numpy()
    term_map[term] = pred_probs[0,:]

# %% [markdown]
# ## Load coordinates for brain structures

# %%
c = pd.read_csv("data/brain/labels.csv", index_col=None, header=0)
struct2coord = {}
for struct, x, y, z in zip(c["PREPROCESSED"], c["X"], c["Y"], c["Z"]):
    struct2coord[struct] = mni2vox(x, y, z)

# %% [markdown]
# ## Specify plotting parameters

# %%
n_top = 15 # Number of terms (i.e., inputs) to plot per structure (i.e., class)
colors = ["#873434", "#bc7a29", "#426033", "#5673ad", "#7f5796"] * 50
cmaps = ["Reds", "Oranges", "Greens", "Blues", "Purples"] * 50
fname = "figures/style/computer-modern/cmunss.ttf"

# %% [markdown]
# ## Plot brain maps and word clouds

# %%
verbose = False
for i, struct in enumerate(act_bin.columns):
    struct = act_bin.columns[i]
    outfile = "figures/maps/{}/{}.png".format(prefix, struct)
    
    if not os.path.exists(outfile):
        x, y, z = struct2coord[struct]
        if verbose:
            print("{} (z={})".format(struct.title().replace("_", " "), int(z)))
        if not verbose:
            plt.ioff()

        fig, ax = plt.subplots(1,2, figsize=(6,6))
        gs1 = gridspec.GridSpec(1,2)
        gs1.update(wspace=-20, hspace=-10)
        fig.suptitle(c["PRESENTABLE_TITLE"][i], y=0.79,
                     fontproperties=font_manager.FontProperties(fname=fname, size=24))

        bg_img = image.load_img("data/brain/atlases/MNI152_T1_1mm_brain.nii.gz")
        bg_img = np.flip(np.rot90(bg_img.get_data()[:,:,int(z)]).astype(float), axis=1)
        bg_img[bg_img == 0] = np.nan
        bg_img = bg_img[10:198, 20:162]

        bilateral_atlas = load_atlas()
        struct_img = np.flip(np.rot90(bilateral_atlas.get_data()[:,:,int(z)]), axis=1)
        struct_img[struct_img != i+1] = np.nan
        struct_img[struct_img == i+1] = 1.0
        struct_img[struct_img == 0] = np.nan
        struct_img = struct_img[10:198, 20:162]
    
        ax[0].imshow(bg_img, cmap="Greys_r", alpha=0.7, vmin=1)
        ax[0].imshow(struct_img, cmap=cmaps[0], alpha=0.6, vmin=0, vmax=1)
        for side in ["left", "right", "top", "bottom"]:
            ax[0].spines[side].set_visible(False)
        ax[0].set_xticks([])
        ax[0].set_yticks([])

        def color_func(word, font_size, position, orientation, 
                   random_state=None, idx=0, **kwargs):
            return colors[0]

        top = term_map.loc[struct].sort_values(ascending=False)[:n_top]
        vals = top.values
        tkns = [t.replace("_", " ") for t in top.index]
        cloud = WordCloud(background_color="rgba(255, 255, 255, 0)", mode="RGB", 
                          max_font_size=180, min_font_size=10, 
                          prefer_horizontal=1, scale=20, margin=3,
                          width=1200, height=1400, font_path=fname, 
                          random_state=42).generate_from_frequencies(zip(tkns, vals))
        ax[1].imshow(cloud.recolor(color_func=color_func, random_state=42))
        ax[1].axis("off")

        plt.savefig(outfile, bbox_inches="tight", dpi=250)
        if verbose:
            plt.show()
        plt.close()
# Out:
# Exception ignored in: <bound method Image.__del__ of <PIL.Image.Image image mode=RGB size=24000x28000 at 0x1A23A5EB00>>
# Traceback (most recent call last):
#   File "/Users/ehbeam/anaconda/envs/ontol/lib/python3.6/site-packages/PIL/Image.py", line 617, in __del__
#     def __del__(self):
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-5b37726e6334> in <module>
#      19     bg_img = bg_img[10:198, 20:162]
#      20
# ---> 21     bilateral_atlas = load_atlas()
#      22     struct_img = np.flip(np.rot90(bilateral_atlas.get_data()[:,:,int(z)]), axis=1)
#      23     struct_img[struct_img != i+1] = np.nan
#
# ~/Dropbox/Stanford/PhD/Classes/Quarter 7/Deep Learning/Project/context2brain/utilities.py in load_atlas()
#     204         sub_lab_dic_R = {15:1, 16:2, 17:3, 18:4, 19:5, 20:6, 21:7, 7:8}
#     205
# --> 206         sub_mat_L = image.load_img(sub).get_data()[91:,:,:]
#     207         sub_mat_R = image.load_img(sub).get_data()[:91,:,:]
#     208
#
# ~/.local/lib/python3.6/site-packages/nilearn/image/image.py in load_img(img, wildcards, dtype)
#     923         that the returned object has get_data() and affine attributes.
#     924     """
# --> 925     return check_niimg(img, wildcards=wildcards, dtype=dtype)
#     926
#     927
#
# ~/.local/lib/python3.6/site-packages/nilearn/_utils/niimg_conversions.py in check_niimg(niimg, ensure_ndim, atleast_4d, dtype, return_iterator, wildcards)
#     269
#     270     # Otherwise, it should be a filename or a SpatialImage, we load it
# --> 271     niimg = load_niimg(niimg, dtype=dtype)
#     272
#     273     if ensure_ndim == 3 and len(niimg.shape) == 4 and niimg.shape[3] == 1:
#
# ~/.local/lib/python3.6/site-packages/nilearn/_utils/niimg.py in load_niimg(niimg, dtype)
#     114                         + short_repr(niimg))
#     115
# --> 116     dtype = _get_target_dtype(niimg.get_data().dtype, dtype)
#     117
#     118     if dtype is not None:
#
# ~/.local/lib/python3.6/site-packages/nibabel/dataobj_images.py in get_data(self, caching)
#     200         if self._data_cache is not None:
#     201             return self._data_cache
# --> 202         data = np.asanyarray(self._dataobj)
#     203         if caching == 'fill':
#     204             self._data_cache = data
#
# ~/anaconda/envs/ontol/lib/python3.6/site-packages/numpy/core/numeric.py in asanyarray(a, dtype, order)
#     551
#     552     """
# --> 553     return array(a, dtype, copy=False, order=order, subok=True)
#     554
#     555
#
# ~/.local/lib/python3.6/site-packages/nibabel/arrayproxy.py in __array__(self)
#     288     def __array__(self):
#     289         # Read array and scale
# --> 290         raw_data = self.get_unscaled()
#     291         return apply_read_scaling(raw_data, self._slope, self._inter)
#     292
#
# ~/.local/lib/python3.6/site-packages/nibabel/arrayproxy.py in get_unscaled(self)
#     283                                        offset=self._offset,
#     284                                        order=self.order,
# --> 285                                        mmap=self._mmap)
#     286         return raw_data
#     287
#
# ~/.local/lib/python3.6/site-packages/nibabel/volumeutils.py in array_from_file(shape, in_dtype, infile, offset, order, mmap)
#     522     if hasattr(infile, 'readinto'):
#     523         data_bytes = bytearray(n_bytes)
# --> 524         n_read = infile.readinto(data_bytes)
#     525         needs_copy = False
#     526     else:
#
# ~/anaconda/envs/ontol/lib/python3.6/gzip.py in read(self, size)
#     274             import errno
#     275             raise OSError(errno.EBADF, "read() on write-only GzipFile object")
# --> 276         return self._buffer.read(size)
#     277
#     278     def read1(self, size=-1):
#
# ~/anaconda/envs/ontol/lib/python3.6/_compression.py in readinto(self, b)
#      66     def readinto(self, b):
#      67         with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68             data = self.read(len(byte_view))
#      69             byte_view[:len(data)] = data
#      70         return len(data)
#
# ~/anaconda/envs/ontol/lib/python3.6/gzip.py in read(self, size)
#     469             buf = self._fp.read(io.DEFAULT_BUFFER_SIZE)
#     470
# --> 471             uncompress = self._decompressor.decompress(buf, size)
#     472             if self._decompressor.unconsumed_tail != b"":
#     473                 self._fp.prepend(self._decompressor.unconsumed_tail)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Combine into one figure

# %%
import os
from PIL import Image, ImageOps

# %%
images = ["figures/maps/{}/{}.png".format(prefix, struct) for struct in act_bin.columns]
img_w, img_h = Image.open(images[0]).size

# %%
pad_w, pad_h = 60, 30
img_w += pad_w * 2
img_h += pad_h * 2
n_row, n_col = 19, 6
fig_w = n_col * img_w
fig_h = n_row * img_h
x_coords = list(range(0, fig_w, img_w)) * n_row
y_coords = np.repeat(list(range(0, fig_h, img_h)), n_col)
padding = (pad_w, pad_h, pad_w, pad_h)
white = (255,255,255,0)

# %%
figure = Image.new("RGB", (fig_w, fig_h), color=white)
for i, img in enumerate(images):
    img = Image.open(img)
    img = ImageOps.expand(img, padding, fill=white)
    figure.paste(img, (x_coords[i], y_coords[i]))
figure.save("figures/maps/{}_map.png".format(prefix))
figure
